# %% [markdown]
# # Mini Project 1: Basic Student Performance Analysis
#
# **Objective**: Develop a Python program to analyze basic student performance metrics using fundamental Python concepts.
#
# **Dataset**: [StudentsPerformance.csv](https://www.kaggle.com/datasets/spscientist/students-performance-in-exams)

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("C:\\Users\\Janhavi\\Downloads\\StudentsPerformance.csv")
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# Create average score column
df['average_score'] = df[['math score', 'reading score', 'writing score']].mean(axis=1)

# Format 'race/ethnicity' for string operation example
df['race/ethnicity'] = df['race/ethnicity'].str.replace('group ', 'Group ').str.upper()

df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        GROUP B           bachelor's degree      standard
# 1  female        GROUP C                some college      standard
# 2  female        GROUP B             master's degree      standard
# 3    male        GROUP A          associate's degree  free/reduced
# 4    male        GROUP C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    average_score
# 0      72.666667
# 1      82.333333
# 2      92.666667
# 3      49.333333
# 4      76.333333

# %%
def classify_student(avg):
    return 'Pass' if avg >= 50 else 'Fail'

def get_topper(df):
    topper = df.loc[df['average_score'].idxmax()]
    return topper['gender'], topper['average_score']

def get_weakest(df):
    weakest = df.loc[df['average_score'].idxmin()]
    return weakest['gender'], weakest['average_score']

# %%
# Apply classification
df['result'] = df['average_score'].apply(classify_student)

# Display results
for index, row in df.iterrows():
    if pd.isnull(row['average_score']):
        print(f"Skipping row {index} due to invalid score.")
        continue
    if row['average_score'] == 100:
        print(f"Perfect score found at row {index}! Stopping early.")
        break
    print(f"{row['gender'].title()} - Avg: {row['average_score']:.2f}, Result: {row['result']}")
# Out:
# Female - Avg: 72.67, Result: Pass
# Female - Avg: 82.33, Result: Pass
# Female - Avg: 92.67, Result: Pass
# Male - Avg: 49.33, Result: Fail
# Male - Avg: 76.33, Result: Pass
# Female - Avg: 77.33, Result: Pass
# Female - Avg: 91.67, Result: Pass
# Male - Avg: 40.67, Result: Fail
# Male - Avg: 65.00, Result: Pass
# Female - Avg: 49.33, Result: Fail
# Male - Avg: 54.67, Result: Pass
# Male - Avg: 45.00, Result: Fail
# Female - Avg: 73.00, Result: Pass
# Male - Avg: 73.33, Result: Pass
# Female - Avg: 53.67, Result: Pass
# Female - Avg: 74.00, Result: Pass
# Male - Avg: 87.67, Result: Pass
# Female - Avg: 26.00, Result: Fail
# Male - Avg: 44.67, Result: Fail
# Female - Avg: 57.67, Result: Pass
# Male - Avg: 66.00, Result: Pass
# Female - Avg: 70.00, Result: Pass
# Male - Avg: 50.33, Result: Pass
# Female - Avg: 71.67, Result: Pass
# Male - Avg: 75.00, Result: Pass
# Male - Avg: 73.00, Result: Pass
# Male - Avg: 59.33, Result: Pass
# Female - Avg: 70.33, Result: Pass
# Male - Avg: 68.33, Result: Pass
# Female - Avg: 69.00, Result: Pass
# Female - Avg: 72.33, Result: Pass
# Female - Avg: 63.00, Result: Pass
# Female - Avg: 64.33, Result: Pass
# Male - Avg: 40.00, Result: Fail
# Male - Avg: 88.67, Result: Pass
# Male - Avg: 80.33, Result: Pass
# Female - Avg: 79.33, Result: Pass
# Female - Avg: 57.67, Result: Pass
# Female - Avg: 84.33, Result: Pass
# Male - Avg: 56.67, Result: Pass
# Male - Avg: 56.67, Result: Pass
# Female - Avg: 66.33, Result: Pass
# Female - Avg: 58.67, Result: Pass
# Male - Avg: 63.33, Result: Pass
# Female - Avg: 53.33, Result: Pass
# Male - Avg: 58.67, Result: Pass
# Female - Avg: 60.67, Result: Pass
# Female - Avg: 71.00, Result: Pass
# Female - Avg: 69.00, Result: Pass
# Male - Avg: 82.67, Result: Pass
# Male - Avg: 52.00, Result: Pass
# Male - Avg: 71.33, Result: Pass
# Male - Avg: 46.33, Result: Fail
# Male - Avg: 80.33, Result: Pass
# Female - Avg: 80.67, Result: Pass
# Female - Avg: 39.00, Result: Fail
# Female - Avg: 84.33, Result: Pass
# Male - Avg: 52.00, Result: Pass
# Male - Avg: 58.33, Result: Pass
# Female - Avg: 9.00, Result: Fail
# Male - Avg: 75.00, Result: Pass
# Male - Avg: 37.33, Result: Fail
# Male - Avg: 59.33, Result: Pass
# Female - Avg: 73.33, Result: Pass
# Female - Avg: 58.67, Result: Pass
# Male - Avg: 64.00, Result: Pass
# Male - Avg: 39.67, Result: Fail
# Female - Avg: 68.67, Result: Pass
# Male - Avg: 58.33, Result: Pass
# Female - Avg: 53.33, Result: Pass
# Female - Avg: 64.67, Result: Pass
# Male - Avg: 60.33, Result: Pass
# Female - Avg: 46.67, Result: Fail
# Male - Avg: 58.00, Result: Pass
# Male - Avg: 46.33, Result: Fail
# Male - Avg: 41.00, Result: Fail
# Male - Avg: 26.00, Result: Fail
# Male - Avg: 79.67, Result: Pass
# Female - Avg: 69.00, Result: Pass
# Female - Avg: 66.00, Result: Pass
# Female - Avg: 48.67, Result: Fail
# Male - Avg: 46.33, Result: Fail
# Male - Avg: 50.33, Result: Pass
# Male - Avg: 66.33, Result: Pass
# Male - Avg: 38.33, Result: Fail
# Female - Avg: 78.33, Result: Pass
# Female - Avg: 82.33, Result: Pass
# Female - Avg: 72.00, Result: Pass
# Female - Avg: 65.00, Result: Pass
# Female - Avg: 80.33, Result: Pass
# Female - Avg: 70.33, Result: Pass
# Male - Avg: 32.33, Result: Fail
# Male - Avg: 73.67, Result: Pass
# Male - Avg: 46.00, Result: Fail
# Female - Avg: 85.67, Result: Pass
# Male - Avg: 80.33, Result: Pass
# Male - Avg: 64.33, Result: Pass
# Female - Avg: 68.33, Result: Pass
# Female - Avg: 62.33, Result: Pass
# Female - Avg: 64.67, Result: Pass
# Male - Avg: 71.00, Result: Pass
# Male - Avg: 72.00, Result: Pass
# Female - Avg: 88.33, Result: Pass
# Male - Avg: 50.33, Result: Pass
# Male - Avg: 91.33, Result: Pass
# Female - Avg: 65.67, Result: Pass
# Female - Avg: 95.67, Result: Pass
# Male - Avg: 64.33, Result: Pass
# Female - Avg: 66.00, Result: Pass
# Female - Avg: 68.67, Result: Pass
# Female - Avg: 88.00, Result: Pass
# Male - Avg: 55.33, Result: Pass
# Male - Avg: 51.33, Result: Pass
# Female - Avg: 54.33, Result: Pass
# Female - Avg: 99.67, Result: Pass
# Male - Avg: 78.33, Result: Pass
# Female - Avg: 80.67, Result: Pass
# Female - Avg: 79.67, Result: Pass
# Female - Avg: 58.33, Result: Pass
# Female - Avg: 63.00, Result: Pass
# Female - Avg: 86.67, Result: Pass
# Male - Avg: 90.67, Result: Pass
# Female - Avg: 91.33, Result: Pass
# Male - Avg: 58.67, Result: Pass
# Male - Avg: 78.67, Result: Pass
# Female - Avg: 89.33, Result: Pass
# Male - Avg: 69.00, Result: Pass
# Male - Avg: 72.00, Result: Pass
# Male - Avg: 79.33, Result: Pass
# Female - Avg: 50.33, Result: Pass
# Male - Avg: 85.00, Result: Pass
# Male - Avg: 43.33, Result: Fail
# Male - Avg: 77.00, Result: Pass
# Female - Avg: 80.00, Result: Pass
# Male - Avg: 76.00, Result: Pass
# Male - Avg: 53.67, Result: Pass
# Male - Avg: 48.67, Result: Fail
# Male - Avg: 60.33, Result: Pass
# Female - Avg: 64.00, Result: Pass
# Male - Avg: 67.00, Result: Pass
# Female - Avg: 73.00, Result: Pass
# Female - Avg: 61.67, Result: Pass
# Female - Avg: 50.33, Result: Pass
# Male - Avg: 49.00, Result: Fail
# Male - Avg: 79.67, Result: Pass
# Female - Avg: 31.33, Result: Fail
# Male - Avg: 82.33, Result: Pass
# Male - Avg: 69.00, Result: Pass
# Female - Avg: 74.67, Result: Pass
# Male - Avg: 97.67, Result: Pass
# Male - Avg: 66.00, Result: Pass
# Male - Avg: 70.67, Result: Pass
# Female - Avg: 65.00, Result: Pass
# Male - Avg: 50.00, Result: Pass
# Male - Avg: 63.33, Result: Pass
# Female - Avg: 82.33, Result: Pass
# Female - Avg: 72.67, Result: Pass
# Male - Avg: 60.00, Result: Pass
# Female - Avg: 78.00, Result: Pass
# Male - Avg: 64.00, Result: Pass
# Male - Avg: 78.00, Result: Pass
# Female - Avg: 82.67, Result: Pass
# Male - Avg: 51.33, Result: Pass
# Male - Avg: 51.33, Result: Pass
# Female - Avg: 88.00, Result: Pass
# Female - Avg: 98.67, Result: Pass
# Male - Avg: 51.67, Result: Pass
# Female - Avg: 70.67, Result: Pass
# Female - Avg: 76.33, Result: Pass
# Female - Avg: 70.67, Result: Pass
# Male - Avg: 73.00, Result: Pass
# Male - Avg: 86.67, Result: Pass
# Female - Avg: 82.00, Result: Pass
# Female - Avg: 66.67, Result: Pass
# Female - Avg: 49.33, Result: Fail
# Female - Avg: 86.33, Result: Pass
# Female - Avg: 52.67, Result: Pass
# Female - Avg: 75.00, Result: Pass
# Female - Avg: 61.33, Result: Pass
# Female - Avg: 99.00, Result: Pass
# Male - Avg: 68.33, Result: Pass
# Female - Avg: 58.67, Result: Pass
# Female - Avg: 49.00, Result: Fail
# Female - Avg: 68.00, Result: Pass
# Male - Avg: 48.67, Result: Fail
# Male - Avg: 65.67, Result: Pass
# Male - Avg: 73.67, Result: Pass
# Male - Avg: 65.33, Result: Pass
# Male - Avg: 48.33, Result: Fail
# Female - Avg: 84.00, Result: Pass
# Female - Avg: 66.67, Result: Pass
# Male - Avg: 79.33, Result: Pass
# Female - Avg: 64.00, Result: Pass
# Male - Avg: 67.00, Result: Pass
# Female - Avg: 79.33, Result: Pass
# Male - Avg: 56.00, Result: Pass
# Male - Avg: 64.33, Result: Pass
# Male - Avg: 54.00, Result: Pass
# Female - Avg: 51.00, Result: Pass
# Female - Avg: 77.67, Result: Pass
# Female - Avg: 79.00, Result: Pass
# Female - Avg: 74.33, Result: Pass
# Male - Avg: 71.67, Result: Pass
# Female - Avg: 64.67, Result: Pass
# Male - Avg: 47.33, Result: Fail
# Male - Avg: 74.33, Result: Pass
# Male - Avg: 68.67, Result: Pass
# Male - Avg: 79.00, Result: Pass
# Female - Avg: 77.00, Result: Pass
# Female - Avg: 61.67, Result: Pass
# Male - Avg: 79.33, Result: Pass
# Male - Avg: 30.00, Result: Fail
# Female - Avg: 54.67, Result: Pass
# Male - Avg: 55.67, Result: Pass
# Male - Avg: 86.33, Result: Pass
# Male - Avg: 80.67, Result: Pass
# Female - Avg: 85.67, Result: Pass
# Female - Avg: 38.33, Result: Fail
# Male - Avg: 71.00, Result: Pass
# Male - Avg: 57.67, Result: Pass
# Female - Avg: 66.00, Result: Pass
# Male - Avg: 81.67, Result: Pass
# Female - Avg: 60.67, Result: Pass
# Male - Avg: 80.33, Result: Pass
# Female - Avg: 63.67, Result: Pass
# Female - Avg: 51.67, Result: Pass
# Female - Avg: 71.67, Result: Pass
# Male - Avg: 53.67, Result: Pass
# Male - Avg: 68.00, Result: Pass
# Female - Avg: 92.33, Result: Pass
# Male - Avg: 68.67, Result: Pass
# Male - Avg: 43.67, Result: Fail
# Female - Avg: 78.67, Result: Pass
# Male - Avg: 85.67, Result: Pass
# Male - Avg: 83.00, Result: Pass
# Male - Avg: 77.33, Result: Pass
# Male - Avg: 65.33, Result: Pass
# Female - Avg: 66.00, Result: Pass
# Male - Avg: 52.33, Result: Pass
# Male - Avg: 81.33, Result: Pass
# Male - Avg: 69.00, Result: Pass
# Female - Avg: 82.00, Result: Pass
# Female - Avg: 54.33, Result: Pass
# Male - Avg: 51.00, Result: Pass
# Male - Avg: 72.67, Result: Pass
# Male - Avg: 77.33, Result: Pass
# Male - Avg: 79.67, Result: Pass
# Female - Avg: 65.33, Result: Pass
# Female - Avg: 63.67, Result: Pass
# Male - Avg: 60.33, Result: Pass
# Male - Avg: 48.33, Result: Fail
# Female - Avg: 79.00, Result: Pass
# Female - Avg: 66.67, Result: Pass
# Male - Avg: 77.33, Result: Pass
# Male - Avg: 52.67, Result: Pass
# Female - Avg: 68.33, Result: Pass
# Female - Avg: 68.33, Result: Pass
# Male - Avg: 77.33, Result: Pass
# Female - Avg: 74.33, Result: Pass
# Female - Avg: 75.67, Result: Pass
# Female - Avg: 73.33, Result: Pass
# Male - Avg: 78.67, Result: Pass
# Female - Avg: 48.33, Result: Fail
# Female - Avg: 94.00, Result: Pass
# Male - Avg: 72.33, Result: Pass
# Male - Avg: 47.33, Result: Fail
# Female - Avg: 73.00, Result: Pass
# Female - Avg: 72.67, Result: Pass
# Female - Avg: 91.67, Result: Pass
# Female - Avg: 72.33, Result: Pass
# Male - Avg: 64.33, Result: Pass
# Male - Avg: 49.67, Result: Fail
# Female - Avg: 52.67, Result: Pass
# Female - Avg: 68.67, Result: Pass
# Male - Avg: 83.00, Result: Pass
# Male - Avg: 78.00, Result: Pass
# Female - Avg: 90.00, Result: Pass
# Female - Avg: 65.67, Result: Pass
# Female - Avg: 77.00, Result: Pass
# Male - Avg: 62.00, Result: Pass
# Male - Avg: 49.00, Result: Fail
# Male - Avg: 46.33, Result: Fail
# Female - Avg: 78.67, Result: Pass
# Female - Avg: 75.33, Result: Pass
# Female - Avg: 43.00, Result: Fail
# Male - Avg: 81.67, Result: Pass
# Male - Avg: 89.00, Result: Pass
# Female - Avg: 79.33, Result: Pass
# Male - Avg: 79.67, Result: Pass
# Male - Avg: 76.67, Result: Pass
# Male - Avg: 71.33, Result: Pass
# Male - Avg: 76.33, Result: Pass
# Male - Avg: 60.00, Result: Pass
# Female - Avg: 71.00, Result: Pass
# Male - Avg: 78.33, Result: Pass
# Male - Avg: 63.00, Result: Pass
# Male - Avg: 43.33, Result: Fail
# Male - Avg: 71.00, Result: Pass
# Male - Avg: 45.33, Result: Fail
# Male - Avg: 84.00, Result: Pass
# Male - Avg: 80.00, Result: Pass
# Male - Avg: 54.00, Result: Pass
# Female - Avg: 77.33, Result: Pass
# Male - Avg: 73.33, Result: Pass
# Female - Avg: 77.33, Result: Pass
# Male - Avg: 68.33, Result: Pass
# Male - Avg: 89.00, Result: Pass
# Male - Avg: 49.00, Result: Fail
# Female - Avg: 63.67, Result: Pass
# Female - Avg: 52.67, Result: Pass
# Female - Avg: 76.33, Result: Pass
# Male - Avg: 61.00, Result: Pass
# Male - Avg: 65.33, Result: Pass
# Female - Avg: 68.00, Result: Pass
# Female - Avg: 66.00, Result: Pass
# Male - Avg: 67.33, Result: Pass
# Female - Avg: 83.33, Result: Pass
# Male - Avg: 77.67, Result: Pass
# Male - Avg: 67.67, Result: Pass
# Female - Avg: 61.33, Result: Pass
# Female - Avg: 76.67, Result: Pass
# Female - Avg: 80.00, Result: Pass
# Female - Avg: 77.33, Result: Pass
# Female - Avg: 49.67, Result: Fail
# Female - Avg: 43.33, Result: Fail
# Female - Avg: 88.67, Result: Pass
# Male - Avg: 61.33, Result: Pass
# Male - Avg: 23.33, Result: Fail
# Male - Avg: 78.00, Result: Pass
# Female - Avg: 49.00, Result: Fail
# Male - Avg: 64.00, Result: Pass
# Male - Avg: 39.67, Result: Fail
# Male - Avg: 57.00, Result: Pass
# Male - Avg: 83.00, Result: Pass
# Female - Avg: 90.33, Result: Pass
# Female - Avg: 65.00, Result: Pass
# Male - Avg: 71.67, Result: Pass
# Male - Avg: 47.67, Result: Fail
# Female - Avg: 29.67, Result: Fail
# Female - Avg: 50.00, Result: Pass
# Male - Avg: 57.00, Result: Pass
# Female - Avg: 65.67, Result: Pass
# Female - Avg: 73.00, Result: Pass
# Male - Avg: 68.67, Result: Pass
# Male - Avg: 73.00, Result: Pass
# Female - Avg: 75.67, Result: Pass
# Male - Avg: 60.00, Result: Pass
# Female - Avg: 88.67, Result: Pass
# Male - Avg: 71.67, Result: Pass
# Male - Avg: 79.00, Result: Pass
# Female - Avg: 62.00, Result: Pass
# Male - Avg: 58.33, Result: Pass
# Female - Avg: 73.67, Result: Pass
# Female - Avg: 53.67, Result: Pass
# Female - Avg: 66.67, Result: Pass
# Female - Avg: 67.67, Result: Pass
# Male - Avg: 61.67, Result: Pass
# Female - Avg: 59.00, Result: Pass
# Male - Avg: 60.67, Result: Pass
# Female - Avg: 86.33, Result: Pass
# Female - Avg: 59.67, Result: Pass
# Male - Avg: 82.33, Result: Pass
# Female - Avg: 56.00, Result: Pass
# Female - Avg: 31.00, Result: Fail
# Male - Avg: 59.00, Result: Pass
# Male - Avg: 55.67, Result: Pass
# Male - Avg: 60.00, Result: Pass
# Male - Avg: 62.67, Result: Pass
# Female - Avg: 55.33, Result: Pass
# Female - Avg: 80.67, Result: Pass
# Male - Avg: 77.33, Result: Pass
# Female - Avg: 62.67, Result: Pass
# Male - Avg: 73.33, Result: Pass
# Female - Avg: 91.67, Result: Pass
# Female - Avg: 67.33, Result: Pass
# Male - Avg: 43.33, Result: Fail
# Female - Avg: 84.00, Result: Pass
# Female - Avg: 93.33, Result: Pass
# Female - Avg: 77.00, Result: Pass
# Male - Avg: 64.00, Result: Pass
# Female - Avg: 83.00, Result: Pass
# Male - Avg: 94.00, Result: Pass
# Male - Avg: 77.00, Result: Pass
# Female - Avg: 44.00, Result: Fail
# Female - Avg: 41.33, Result: Fail
# Female - Avg: 72.67, Result: Pass
# Female - Avg: 69.00, Result: Pass
# Female - Avg: 67.33, Result: Pass
# Female - Avg: 63.33, Result: Pass
# Male - Avg: 72.67, Result: Pass
# Male - Avg: 66.33, Result: Pass
# Female - Avg: 74.00, Result: Pass
# Male - Avg: 70.00, Result: Pass
# Male - Avg: 55.67, Result: Pass
# Female - Avg: 72.00, Result: Pass
# Male - Avg: 44.67, Result: Fail
# Female - Avg: 60.00, Result: Pass
# Female - Avg: 89.67, Result: Pass
# Male - Avg: 64.67, Result: Pass
# Male - Avg: 57.67, Result: Pass
# Female - Avg: 60.00, Result: Pass
# Male - Avg: 46.33, Result: Fail
# Female - Avg: 56.33, Result: Pass
# Female - Avg: 95.67, Result: Pass
# Female - Avg: 58.33, Result: Pass
# Female - Avg: 68.00, Result: Pass
# Male - Avg: 64.33, Result: Pass
# Female - Avg: 79.67, Result: Pass
# Female - Avg: 55.00, Result: Pass
# Male - Avg: 85.33, Result: Pass
# Female - Avg: 71.67, Result: Pass
# Male - Avg: 81.67, Result: Pass
# Male - Avg: 65.67, Result: Pass
# Male - Avg: 65.67, Result: Pass
# Female - Avg: 67.33, Result: Pass
# Male - Avg: 75.33, Result: Pass
# Male - Avg: 71.00, Result: Pass
# Male - Avg: 71.33, Result: Pass
# Male - Avg: 63.00, Result: Pass
# Male - Avg: 55.67, Result: Pass
# Female - Avg: 89.33, Result: Pass
# Female - Avg: 59.67, Result: Pass
# Female - Avg: 57.33, Result: Pass
# Female - Avg: 74.67, Result: Pass
# Male - Avg: 38.00, Result: Fail
# Female - Avg: 63.67, Result: Pass
# Male - Avg: 85.00, Result: Pass
# Male - Avg: 68.33, Result: Pass
# Male - Avg: 59.00, Result: Pass
# Male - Avg: 61.67, Result: Pass
# Male - Avg: 63.00, Result: Pass
# Female - Avg: 67.67, Result: Pass
# Male - Avg: 57.33, Result: Pass
# Female - Avg: 52.00, Result: Pass
# Male - Avg: 68.33, Result: Pass
# Male - Avg: 50.33, Result: Pass
# Male - Avg: 69.00, Result: Pass
# Male - Avg: 71.33, Result: Pass
# Male - Avg: 59.00, Result: Pass
# Male - Avg: 86.33, Result: Pass
# Female - Avg: 75.67, Result: Pass
# Female - Avg: 79.67, Result: Pass
# Female - Avg: 67.00, Result: Pass
# Female - Avg: 77.33, Result: Pass
# Male - Avg: 78.00, Result: Pass
# Female - Avg: 72.67, Result: Pass
# Male - Avg: 65.00, Result: Pass
# Male - Avg: 82.33, Result: Pass
# Male - Avg: 45.00, Result: Fail
# Male - Avg: 75.33, Result: Pass
# Female - Avg: 78.00, Result: Pass
# Female - Avg: 96.33, Result: Pass
# Female - Avg: 72.00, Result: Pass
# Male - Avg: 57.33, Result: Pass
# Female - Avg: 58.67, Result: Pass
# Male - Avg: 46.67, Result: Fail
# Female - Avg: 85.67, Result: Pass
# Male - Avg: 51.67, Result: Pass
# Perfect score found at row 458! Stopping early.

# %%
topper_gender, topper_score = get_topper(df)
weakest_gender, weakest_score = get_weakest(df)

print(f"Topper is a {topper_gender} student with an average score of {topper_score:.2f}")
print(f"Weakest is a {weakest_gender} student with an average score of {weakest_score:.2f}")
# Out:
# Topper is a female student with an average score of 100.00
# Weakest is a female student with an average score of 9.00

# %% [markdown]
# ## 📌 Conclusion
#
# In this project, we:
# - Applied basic arithmetic and string operations
# - Classified students using conditional logic
# - Used loops, break and continue statements
# - Wrote functions to modularize logic
